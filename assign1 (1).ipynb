# %%
# connecting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# !ls -l
# Out:
# total 8
# drwx------ 5 root root 4096 May  9 13:59 drive
# drwxr-xr-x 1 root root 4096 May  7 13:22 sample_data

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !mkdir intro-dl
# Out:
# mkdir: cannot create directory ‘intro-dl’: File exists

# %%
# %cd /content/drive/MyDrive/intro-dl
# Out:
# /content/drive/MyDrive/intro-dl

# %%
# !pwd
# Out:
# /content/drive/MyDrive/intro-dl

# %%
# !unzip -qq /content/drive/MyDrive/intro-dl/archive.zip -d /content/drive/MyDrive/intro-dl
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/intro-dl/archive.zip, /content/drive/MyDrive/intro-dl/archive.zip.zip or /content/drive/MyDrive/intro-dl/archive.zip.ZIP.

# %%
# !ls -l
# Out:
# total 4
# drwx------ 2 root root 4096 May  7 14:44 afhq

# %%
# %cd afhq
# Out:
# /content/drive/MyDrive/intro-dl/afhq

# %%
# !ls -l
# Out:
# total 16
# drwx------ 2 root root 4096 May  7 17:36 data
# drwx------ 2 root root 4096 May  7 14:46 new_folder
# drwx------ 2 root root 4096 May  9 13:40 train
# drwx------ 2 root root 4096 May  9 13:41 val

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# %cd /content/sample_data
# Out:
# /content/sample_data

# %%
# !pwd
# Out:
# /content/sample_data

# %%
import os

# %%
os.chdir('/content/sample_data')
os.getcwd()
# Out:
# '/content/sample_data'

# %%
os.mkdir('/content/drive/MyDrive/intro-dl/afhq')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-18-21a51b9dec19> in <cell line: 1>()
# ----> 1 os.mkdir('/content/drive/MyDrive/intro-dl/afhq')
#
# FileExistsError: [Errno 17] File exists: '/content/drive/MyDrive/intro-dl/afhq'

# %%
os.listdir(os.getcwd())
# Out:
# ['anscombe.json',
#  'README.md',
#  'california_housing_train.csv',
#  'mnist_train_small.csv',
#  'mnist_test.csv',
#  'california_housing_test.csv']

# %%
## shutil

# %%
import shutil

# %%
os.chdir('/content/drive/MyDrive/intro-dl/afhq')

# %%
# !ls -l
# Out:
# total 16
# drwx------ 2 root root 4096 May  7 17:36 data
# drwx------ 2 root root 4096 May  7 14:46 new_folder
# drwx------ 2 root root 4096 May  9 13:40 train
# drwx------ 2 root root 4096 May  9 13:41 val

# %%
f =open("new.txt", 'w')

# %%
f.close()

# %%
# !ls -l
# Out:
# total 16
# drwx------ 2 root root 4096 May  7 17:36 data
# drwx------ 2 root root 4096 May  7 14:46 new_folder
# -rw------- 1 root root    0 May  9 14:02 new.txt
# drwx------ 2 root root 4096 May  9 13:40 train
# drwx------ 2 root root 4096 May  9 13:41 val

# %%
# !mkdir new_folder
# Out:
# mkdir: cannot create directory ‘new_folder’: File exists

# %%
# !ls -l
# Out:
# total 16
# drwx------ 2 root root 4096 May  7 17:36 data
# drwx------ 2 root root 4096 May  7 14:46 new_folder
# -rw------- 1 root root    0 May  9 14:02 new.txt
# drwx------ 2 root root 4096 May  9 13:40 train
# drwx------ 2 root root 4096 May  9 13:41 val

# %%
src = '/content/drive/MyDrive/intro-dl/afhq/new.txt'
dst = '/content/drive/MyDrive/intro-dl/afhq/new_folder/new.txt'

# %%
shutil.move(src, dst)
# Out:
# '/content/drive/MyDrive/intro-dl/afhq/new_folder/new.txt'

# %%
# %cd /content/drive/MyDrive/intro-dl/afhq/new_folder
# Out:
# /content/drive/MyDrive/intro-dl/afhq/new_folder

# %%
# !ls -l
# Out:
# total 0
# -rw------- 1 root root 0 May  7 14:48 new2.txt
# -rw------- 1 root root 0 May  7 14:57 new3.txt
# -rw------- 1 root root 0 May  9 14:02 new.txt

# %%
src2 = '/content/drive/MyDrive/intro-dl/afhq/new_folder/new.txt'
dst2 = '/content/drive/MyDrive/intro-dl/afhq/new_folder/new2.txt'

# %%
shutil.copy(src2, dst2)
# Out:
# '/content/drive/MyDrive/intro-dl/afhq/new_folder/new2.txt'

# %%
# !ls -l
# Out:
# total 0
# -rw------- 1 root root 0 May  9 14:02 new2.txt
# -rw------- 1 root root 0 May  7 14:57 new3.txt
# -rw------- 1 root root 0 May  9 14:02 new.txt

# %% [markdown]
# ## Question 2. Please write a code that copies new.txt with a file name new3.txt.

# %%
src3 = '/content/drive/MyDrive/intro-dl/afhq/new_folder/new.txt'
dst3 = '/content/drive/MyDrive/intro-dl/afhq/new_folder/new3.txt'

# %%
shutil.copy(src3, dst3)
# Out:
# '/content/drive/MyDrive/intro-dl/afhq/new_folder/new3.txt'

# %%
# !ls -l
# Out:
# total 0
# -rw------- 1 root root 0 May  9 14:02 new2.txt
# -rw------- 1 root root 0 May  9 14:02 new3.txt
# -rw------- 1 root root 0 May  9 14:02 new.txt

# %%
import torch

# %%
scalar1 = torch.tensor([1.])
print(scalar1)
# Out:
# tensor([1.])

# %%
scalar2 = torch.tensor([3.])
print(scalar2)
# Out:
# tensor([3.])

# %%
torch.div(scalar1, scalar2) # scalar1 / scalar2 # 순서바뀌면 바뀌는거
# Out:
# tensor([0.3333])

# %%
vector1 = torch.tensor([1., 2., 3.])
print(vector1)
# Out:
# tensor([1., 2., 3.])

# %%
vector2 = torch.tensor([4., 5., 6.])
print(vector2)
# Out:
# tensor([4., 5., 6.])

# %% [markdown]
# .

# %%
matrix1 = torch.tensor([[1., 2.], [3., 4.]])
print(matrix1)
# Out:
# tensor([[1., 2.],
#         [3., 4.]])

# %%
matrix2 = torch.tensor([[5., 6.], [7., 8.]])
print(matrix2)
# Out:
# tensor([[5., 6.],
#         [7., 8.]])

# %%
torch.mul(matrix1, matrix2)
# Out:
# tensor([[ 5., 12.],
#         [21., 32.]])

# %%
torch.matmul(matrix1, matrix2)
# Out:
# tensor([[19., 22.],
#         [43., 50.]])

# %% [markdown]
# ## Question 3. Compute L1/L2 Norm between matrix1 and matrix2 above.

# %%
## L1 norm
sub = matrix1 - matrix2
sub = sub.reshape((4))
l1_norm = torch.linalg.norm(sub, ord=1)
print(l1_norm)
# Out:
# tensor(16.)

# %%
## L2 norm
l2_norm = torch.linalg.norm(sub, ord=2)
print(l2_norm)
# Out:
# tensor(8.)

# %%
## Hard Mode (Optional)
## Compute Cosine Similarity between matrix1 and matrix2 above.

## Your Answer

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# ## Question 4. Please write a line-by-line explanation of the code above. (Simple MLP only)
# * Use '#' for Python!
# * ChatGPT allowed :) -- but please try to understand the code
# * But you don't really have to understand everything -- we'll revisit MLP again in detail

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

## 실행 모듈을 불러온다

# %%
if torch.cuda.is_available():
  DEVICE = torch.device('cuda')
else:
  DEVICE = torch.device('cpu')

print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
## cuda121 버전을 사용하면서 cpu환경에서 사용한단다(왜?).
# Out:
# Using PyTorch version: 2.2.1+cu121  Device: cpu

# %%
BATCH_SIZE = 32
EPOCHS = 10
## batch size, epoch 수를 사용자겨 결정(지정)

# %%
''' 3. MNIST Download (Train set, Test set split) '''
train_dataset = datasets.MNIST(root = "../data/MNIST",
                               train = True,
                               download = True,
                               transform = transforms.ToTensor())

test_dataset = datasets.MNIST(root = "../data/MNIST",
                              train = False,
                              transform = transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = BATCH_SIZE,
                                           shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = False)

## mnist 데이터를 다운받고, train, test 세트로 분할해준다.
## transform을 활용해서 이미지를 텐서로 변환한다.
## batchsize로 미니batch로 나눈다.

# %%
## Quick Question
# What is MNIST?
# Google it and write the answer
     ##  손으로 쓴 숫자이미지  datasets

# %%
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break

## for 반복문으로 첫 세트를 출력한 뒤 break로 종료

## X_train : 32개 이미지, 1channel, 28x28사이즈(소수점)
## y_train : 32개 label(정수형)
# Out:
# X_train: torch.Size([32, 1, 28, 28]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %%
pltsize = 1
plt.figure(figsize=(10 * pltsize, pltsize))
for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(X_train[i, :, :, :].numpy().reshape(28, 28), cmap = "gray_r")
    plt.title('Class: ' + str(y_train[i].item()))

## 계속 첫 세트(미니배치)를 이용해서 imshow를 활용해 흑백 이미지로 바꿔준다
## title로 각 class이름을 붙여준다

# %%
''' Multi Layer Perceptron '''
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = self.fc1(x)
        x = F.sigmoid(x)
        x = self.fc2(x)
        x = F.sigmoid(x)
        x = self.fc3(x)
        x = F.log_softmax(x, dim = 1)
        return x

## MLP를 정의하자
## 모델의 구조를 설정하는데 3개의 선형을 사용할거야 -> 28x28사이즈로 512출력크기로 -> 256출력크기로 -> 10 출력크기로

# %%
''' Optimizer, Objective Function '''
model = Net().to(DEVICE)
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum = 0.5)
criterion = nn.CrossEntropyLoss()

print(model)

## 모델을 cpu로 옮기고(원래는 gpu) lr:학습률=0.01, momentum=0.5 로 설정해준다
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image),
                len(train_loader.dataset), 100. * batch_idx / len(train_loader),
                loss.item()))

## 이제 모델을 train시킬건데
## 옵티마이저의 그래디언트를 초기화하고 그 입력된 이미지를 모델에 전달해서 output 얻어냄
## loss로 손실을 계산하고/ 손실 출력

# %%
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()

    test_loss /= (len(test_loader.dataset) / BATCH_SIZE)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

## 모델 평가모델을 가지고 테스트 데이터의 모델 성능을 실험

# %%
for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
        epoch, test_loss, test_accuracy))

## 설정한 epoch만큼 돌려 / 반복/ 돌려(훈련한다)
## 손실과 정확도를 얻는다
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Train Loss: 2.309010
# Train Epoch: 1 [6400/60000 (11%)]	Train Loss: 2.265863
# Train Epoch: 1 [12800/60000 (21%)]	Train Loss: 2.319108
# Train Epoch: 1 [19200/60000 (32%)]	Train Loss: 2.295143
# Train Epoch: 1 [25600/60000 (43%)]	Train Loss: 2.305437
# Train Epoch: 1 [32000/60000 (53%)]	Train Loss: 2.267058
# Train Epoch: 1 [38400/60000 (64%)]	Train Loss: 2.280029
# Train Epoch: 1 [44800/60000 (75%)]	Train Loss: 2.280918
# Train Epoch: 1 [51200/60000 (85%)]	Train Loss: 2.259073
# Train Epoch: 1 [57600/60000 (96%)]	Train Loss: 2.216929
#
# [EPOCH: 1], 	Test Loss: 2.2318, 	Test Accuracy: 18.82 %
#
# Train Epoch: 2 [0/60000 (0%)]	Train Loss: 2.236076
# Train Epoch: 2 [6400/60000 (11%)]	Train Loss: 2.204427
# Train Epoch: 2 [12800/60000 (21%)]	Train Loss: 2.131396
# Train Epoch: 2 [19200/60000 (32%)]	Train Loss: 2.135614
# Train Epoch: 2 [25600/60000 (43%)]	Train Loss: 1.853365
# Train Epoch: 2 [32000/60000 (53%)]	Train Loss: 1.836015
# Train Epoch: 2 [38400/60000 (64%)]	Train Loss: 1.761840
# Train Epoch: 2 [44800/60000 (75%)]	Train Loss: 1.451613
