# %% [markdown]
# ## 3. Image Classification w/ pre-trained ResNet model -- custom dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/intro-dl/hymenoptera
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/intro-dl/hymenoptera'
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive
# Out:
# '1차프로젝트 mydrive'
# 'afhq 4'
# 'brad_01팀_팀미션 제출(1주차).docx'
# 'Colab Notebooks'
# '[DS]18기_python_programming_shinyuri.py'
# '[DS]EDA 과제 2_주유소 데이터 분석 과제 (2).pdf'
#  ds_study
#  intro-dl
# 'NIFTY 50 .html'
# 'shinyuri (1) (1).ipynb'
# 'shinyuri (1).ipynb'
# 'Week.1  자소서 자유양식 필수문항 작성하기.gdoc'
# 'Week.1  자소서 자유양식 필수문항 작성하기 팀5조.gdoc'
# 'Week. 2 [데이터 직군] 공통 항목 면접 질문 5팀.gdoc'
# '노트북 - 복사본.zip'
# '자 기 소 개 서.gdoc'
# '제목 없는 설문지.gform'
#  지원현황.gsheet
# '팀미션 제출(1주차).docx의 사본.docx'

# %%
# !ls /content/drive/MyDrive/intro-dl
# Out:
#  afhq  'afhq (1)'   data

# %%
# %cd /content/drive/MyDrive/intro-dl/hymenoptera
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/intro-dl/hymenoptera'
# /content

# %%
# !mkdir -p /content/drive/MyDrive/intro-dl/hymenoptera

# %%
# %cd /content/drive/MyDrive/intro-dl/hymenoptera
# Out:
# /content/drive/MyDrive/intro-dl/hymenoptera

# %%
# %cd /content/drive/MyDrive/intro-dl/hymenoptera
# Out:
# /content/drive/MyDrive/intro-dl/hymenoptera

# %%
# !unzip archive.zip
# Out:
# unzip:  cannot find or open archive.zip, archive.zip.zip or archive.zip.ZIP.

# %%
ls -l /content/drive/MyDrive/intro-dl/hymenoptera
# Out:
# total 0

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-14234b76-d6ba-45ec-a8a5-565e3a0c8bdb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14234b76-d6ba-45ec-a8a5-565e3a0c8bdb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

# %%
# 런타임 - 런타임 유형 변경 - T4 GPU
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
# Out:
# Using PyTorch version: 2.3.0+cu121  Device: cpu

# %%
BATCH_SIZE = 32
EPOCHS = 10

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ]),
    'val': transforms.Compose([
        transforms.CenterCrop(224),
        transforms.Resize(256),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ]),
}

image_datasets = {x: datasets.ImageFolder("/content/drive/MyDrive/intro-dl/hymenoptera/hymenoptera_data", data_transforms[x]) for x in ['train', 'val']} ## Change Here! (Your directory)
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size = BATCH_SIZE, shuffle = True) for x in ['train', 'val']}
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-5a9549dd400a> in <cell line: 16>()
#      14 }
#      15
# ---> 16 image_datasets = {x: datasets.ImageFolder("/content/drive/MyDrive/intro-dl/hymenoptera/hymenoptera_data", data_transforms[x]) for x in ['train', 'val']} ## Change Here! (Your directory)
#      17 dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size = BATCH_SIZE, shuffle = True) for x in ['train', 'val']}
#
# <ipython-input-7-5a9549dd400a> in <dictcomp>(.0)
#      14 }
#      15
# ---> 16 image_datasets = {x: datasets.ImageFolder("/content/drive/MyDrive/intro-dl/hymenoptera/hymenoptera_data", data_transforms[x]) for x in ['train', 'val']} ## Change Here! (Your directory)
#      17 dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size = BATCH_SIZE, shuffle = True) for x in ['train', 'val']}
#
# ...

# %%
### 이 오류 전에 assign3에서 계속 고쳐지지 않은 오류랑 동일합니다ㅠㅜㅜㅡㅜ
